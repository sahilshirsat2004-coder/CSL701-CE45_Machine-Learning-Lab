# %% [markdown]
# <a href="https://colab.research.google.com/github/sahilshirsat2004-coder/CSL701-CE45_Machine-Learning-Lab/blob/main/pract_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# NAME: SAHIL GANESH SHIRSAT
# ROLL NO : CE45

# %% [markdown]
# • Task 1: Import NumPy, Pandas, Matplotlib.pyplot and Seaborn.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# • Task 2: Load train.csv into a Pandas DataFrame using pd.read_csv().

# %%
from google.colab import files

uploaded = files.upload()

df = pd.read_csv("Titanic-Dataset (1) (6).csv")
# Out:
#      <input type="file" id="files-84d40543-62a6-4de8-a7df-df441db3838f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-84d40543-62a6-4de8-a7df-df441db3838f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# • Task 3: Display first 10 rows using df.head(10).

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %% [markdown]
# • Task 4: Display last 5 rows using df.tail(5).

# %%
df.tail(5)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# Task 5: Check dataset dimensions using df.shape (Expected: 891 x 12).

# %%
print("Dataset Shape:", df.shape)
# Out:
# Dataset Shape: (891, 12)

# %% [markdown]
# Task 6: Display dataset information using df.info().

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# • Task 7: Generate summary statistics using df.describe(); record mean, minimum and
# maximum values of Age and Fare.

# %%
df.describe()
print("Age")
print("Mean :", df["Age"].mean())
print("Minimum :", df["Age"].min())
print("Maximum :", df["Age"].max())

print()

print("Fare")
print("Mean :", df["Fare"].mean())
print("Minimum :", df["Fare"].min())
print("Maximum :", df["Fare"].max())
# Out:
# Age
# Mean : 29.69911764705882
# Minimum : 0.42
# Maximum : 80.0
#
# Fare
# Mean : 32.204207968574636
# Minimum : 0.0
# Maximum : 512.3292

# %% [markdown]
# • Task 8: Identify missing values using df.isnull().sum().

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# • Task 9: Fill missing Age values with the median.

# %%
median_age = df["Age"].median()
df["Age"] = df["Age"].fillna(median_age)

# %% [markdown]
# • Task 10: Filter surviving passengers (Survived == 1).

# %%
survivors = df[df["Survived"] == 1]

survivors.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %% [markdown]
# • Task 11: Convert Fare column to a NumPy array.

# %%
fare_array = df["Fare"].to_numpy()

print(fare_array)
# Out:
# [  7.25    71.2833   7.925   53.1      8.05     8.4583  51.8625  21.075
#   11.1333  30.0708  16.7     26.55     8.05    31.275    7.8542  16.
#   29.125   13.      18.       7.225   26.      13.       8.0292  35.5
#   21.075   31.3875   7.225  263.       7.8792   7.8958  27.7208 146.5208
#    7.75    10.5     82.1708  52.       7.2292   8.05    18.      11.2417
#    9.475   21.       7.8958  41.5792   7.8792   8.05    15.5      7.75
#   21.6792  17.8     39.6875   7.8     76.7292  26.      61.9792  35.5
#   10.5      7.2292  27.75    46.9      7.2292  80.      83.475   27.9
#   27.7208  15.2458  10.5      8.1583   7.925    8.6625  10.5     46.9
#   73.5     14.4542  56.4958   7.65     7.8958   8.05    29.      12.475
#    9.       9.5      7.7875  47.1     10.5     15.85    34.375    8.05
#  263.       8.05     8.05     7.8542  61.175   20.575    7.25     8.05
#   34.6542  63.3583  23.      26.       7.8958   7.8958  77.2875   8.6542
# ...

# %% [markdown]
# • Task 12: Calculate maximum and average Fare using np.max() and np.mean().

# %%
print("Maximum Fare =", np.max(fare_array))

print("Average Fare =", np.mean(fare_array))
# Out:
# Maximum Fare = 512.3292
# Average Fare = 32.204207968574636

# %% [markdown]
# • Task 13: Plot histogram of Age.

# %%
plt.figure(figsize=(8,5))

plt.hist(df["Age"], bins=20, color="skyblue", edgecolor="black")

plt.title("Age Distribution")

plt.xlabel("Age")

plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# • Task 14: Plot bar chart of Survival Count.

# %%
sns.countplot(x="Survived", data=df)

plt.title("Survival Count")

plt.xlabel("Survived")

plt.ylabel("Count")

plt.show()

# %% [markdown]
# • Task 15: Plot scatter graph of Age vs Fare.

# %%
plt.figure(figsize=(8,5))

plt.scatter(df["Age"], df["Fare"], color="red")

plt.title("Age vs Fare")

plt.xlabel("Age")

plt.ylabel("Fare")

plt.show()
